# %% [markdown]
# <a href="https://colab.research.google.com/github/SonyFebri/Machine-Learning/blob/main/week2_praktikum4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
from PIL import Image

img = Image.open('contoh.jpeg')
img.show() # tampilkan gambar
display(img) # metode alternatif tampilkan gambar
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=197x256>

# %%
# Ekstrak setiap channel red, green, blue
r, g, b = img.split()

# Cek panjang ukuran channel red
print(len(r.histogram()))

# Cetak fitur histogram pada channel red
print(r.histogram())
# Out:
# 256
# [914, 74, 73, 75, 86, 68, 60, 64, 76, 63, 44, 57, 32, 45, 27, 34, 33, 28, 23, 19, 23, 17, 13, 17, 11, 20, 20, 14, 8, 21, 16, 17, 17, 16, 13, 17, 16, 10, 11, 24, 10, 13, 13, 18, 15, 17, 23, 16, 13, 12, 15, 13, 16, 12, 13, 14, 19, 11, 19, 16, 21, 12, 11, 25, 19, 18, 25, 18, 26, 17, 14, 17, 18, 20, 20, 21, 25, 16, 32, 13, 16, 17, 24, 19, 16, 22, 33, 21, 31, 13, 25, 23, 28, 26, 25, 23, 28, 20, 25, 20, 25, 22, 31, 28, 23, 31, 32, 25, 28, 27, 30, 22, 25, 25, 36, 27, 26, 27, 26, 19, 31, 23, 26, 26, 27, 24, 26, 26, 33, 26, 36, 35, 37, 32, 35, 37, 32, 34, 26, 39, 31, 36, 28, 32, 28, 21, 30, 27, 28, 33, 35, 44, 36, 30, 36, 44, 31, 37, 33, 32, 37, 30, 32, 41, 38, 32, 31, 44, 41, 38, 35, 42, 33, 45, 35, 39, 45, 42, 50, 46, 35, 32, 45, 54, 43, 51, 41, 44, 57, 49, 53, 51, 50, 62, 49, 49, 56, 80, 70, 55, 61, 62, 49, 72, 74, 69, 71, 78, 71, 66, 68, 60, 71, 87, 98, 87, 93, 85, 102, 89, 79, 62, 74, 90, 102, 66, 96, 78, 88, 93, 94, 92, 89, 95, 81, 106, 115, 123, 145, 164, 175, 167, 210, 233, 274, 300, 351, 395, 437, 472, 547, 618, 663, 721, 808, 33659]
